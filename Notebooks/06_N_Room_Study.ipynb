# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import bempp.api
from bempp.api import shapes
import bempp_cavity

# %%
import grids

# %%
ELEMENT_SIZE = 0.2
LENGTH_CAVITY = 1
LENGTH_WALL = 3

# %%
bempp_cavity.plotting.show_domains(grids.make_grid_3())

# %%
0.65/2 + 0.25
# Out:
# 0.575

# %%
shapes.
